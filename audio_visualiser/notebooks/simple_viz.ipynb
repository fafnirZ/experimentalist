# %%
from audio_viz.wav import Wav
from audio_viz.animator import Animator

# %%
wav = Wav.read(file="../example_data/Duckstep_NCS.wav")

# %%
WINDOW_SECS = 1
Animator.animate(
    Animator.slide_window(WINDOW_SECS, wav)
)
